# %%
import numpy as np
import pandas as pd 
import yfinance as yf

# %%
data = yf.download('AAPL', start='2020-01-01', end='2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['Daily Return'] = data['Adj Close'].pct_change()

# %%
avg_daily_return = data['Daily Return'].mean()
std_daily_return = data['Daily Return'].std()

# %%
risk_free_rate = 0.05

# %%
sharpe_ratio = (avg_daily_return - risk_free_rate / 252) / std_daily_return
annual_sharpe_ratio = sharpe_ratio * np.sqrt(252)
print(f'Annual Sharpe Ratio: {annual_sharpe_ratio}')
# Out:
# Annual Sharpe Ratio: 0.5632049743217762

# %% [markdown]
# CROSS SECTIONAL MOMENTUM

# %%
# Tải dữ liệu của nhiều cổ phiếu (có thể thay đổi danh sách này)
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NFLX', 'META']

data = yf.download(tickers, start='2020-01-01', end='2024-01-01')['Adj Close']

# Tính toán lợi suất hàng ngày (daily returns)
returns = data.pct_change().dropna()

# Tính hiệu suất của mỗi cổ phiếu trong 12 tháng trước đó (252 ngày giao dịch)
lookback_period = 252
momentum_returns = returns.rolling(window=lookback_period).apply(np.sum)

# Lấy dữ liệu hiệu suất của tháng gần nhất để xếp hạng
momentum_last_month = momentum_returns.iloc[-1]
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
# Xếp hạng các cổ phiếu dựa trên lợi suất trong 12 tháng trước đó
top_n = 3  # Số cổ phiếu có hiệu suất tốt nhất
bottom_n = 3  # Số cổ phiếu có hiệu suất kém nhất

# Sắp xếp các cổ phiếu dựa trên hiệu suất
ranked_stocks = momentum_last_month.sort_values(ascending=False)

# Lựa chọn cổ phiếu tốt nhất và kém nhất
winners = ranked_stocks.head(top_n).index  # Mua các cổ phiếu tốt nhất
losers = ranked_stocks.tail(bottom_n).index  # Bán các cổ phiếu kém nhất

print(f"Winners (Buy): {winners}")
print(f"Losers (Sell): {losers}")
# Out:
# Winners (Buy): Index(['META', 'TSLA', 'AMZN'], dtype='object', name='Ticker')
# Losers (Sell): Index(['GOOGL', 'MSFT', 'AAPL'], dtype='object', name='Ticker')

# %%
# Tính lợi suất của nhóm cổ phiếu thắng (winners) và thua (losers) trong tháng tiếp theo
future_returns = returns.iloc[-21:]  # Lợi suất trong tháng tiếp theo (21 ngày giao dịch)

# Lợi nhuận trung bình của các cổ phiếu mua và bán
winners_return = future_returns[winners].mean(axis=1)
losers_return = future_returns[losers].mean(axis=1)

# Lợi nhuận của chiến lược cross-sectional momentum
momentum_strategy_return = winners_return - losers_return

# Tổng lợi suất chiến lược
cumulative_return = (1 + momentum_strategy_return).cumprod()

print(f"Lợi suất chiến lược cumulative return:\n{cumulative_return}")
# Out:
# Lợi suất chiến lược cumulative return:
# Date
# 2023-11-30 00:00:00+00:00    0.993866
# 2023-12-01 00:00:00+00:00    0.995186
# 2023-12-04 00:00:00+00:00    0.995240
# 2023-12-05 00:00:00+00:00    0.988102
# 2023-12-06 00:00:00+00:00    0.990439
# 2023-12-07 00:00:00+00:00    0.987027
# 2023-12-08 00:00:00+00:00    0.995383
# 2023-12-11 00:00:00+00:00    0.989978
# 2023-12-12 00:00:00+00:00    0.995441
# 2023-12-13 00:00:00+00:00    0.996555
# 2023-12-14 00:00:00+00:00    1.016969
# 2023-12-15 00:00:00+00:00    1.022703
# 2023-12-18 00:00:00+00:00    1.032893
# 2023-12-19 00:00:00+00:00    1.040458
# 2023-12-20 00:00:00+00:00    1.023911
# 2023-12-21 00:00:00+00:00    1.035077
# 2023-12-22 00:00:00+00:00    1.029120
# 2023-12-26 00:00:00+00:00    1.036852
# 2023-12-27 00:00:00+00:00    1.049296
# 2023-12-28 00:00:00+00:00    1.037254
# 2023-12-29 00:00:00+00:00    1.025889
# dtype: float64

# %%
# Giả sử lãi suất phi rủi ro là 0.02/năm (tính ra hàng ngày là 0.02/252)
risk_free_rate = 0.02/ (3 * 365)

# Tính Sharpe Ratio
excess_returns = returns - risk_free_rate  # Lợi suất vượt mức
mean_excess_return = excess_returns.mean()  # Lợi suất vượt mức trung bình
std_excess_return = excess_returns.std()  # Độ lệch chuẩn của lợi suất vượt mức

sharpe_ratio = mean_excess_return / std_excess_return
print(f"Sharpe Ratio: {sharpe_ratio}")
# Out:
# Sharpe Ratio: Ticker
# AAPL     0.055250
# AMZN     0.030814
# GOOGL    0.043328
# META     0.032057
# MSFT     0.052388
# NFLX     0.027990
# TSLA     0.071127
# dtype: float64

# %%
from datetime import datetime
import pandas as pd
import requests
import time

def to_timestamp(date_string):
    return int(datetime.strptime(date_string, "%d-%m-%Y %H:%M").timestamp())

def to_utc_date(timestamp):
    return datetime.utcfromtimestamp(int(timestamp)).strftime('%d-%m-%Y %H:%M')

def current_timestamp():
    return int(datetime.now().timestamp())

def progressBar(iterable, prefix = '', suffix = '', decimals = 1, length = 100, fill = '█', printEnd = "\r"):
    total = len(iterable)
    def printProgressBar (iteration):
        percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
        filledLength = int(length * iteration // total)
        bar = fill * filledLength + '-' * (length - filledLength)
        print(f'\r{prefix} |{bar}| {percent}% {suffix}', end = printEnd)
    printProgressBar(0)
    for i, item in enumerate(iterable):
        yield item
        printProgressBar(i + 1)
    print()

if __name__ == '__main__':
    start = '01-09-2020 00:00'
    end = None

    currency_pair = 'BTC'
    pair_sufix = 'inverse'
    interval = 1
    wait_count = 3

    start_date = to_timestamp(start)
    end_date = current_timestamp() if end == None else to_timestamp(end)
    if end == None:
        end = to_utc_date(end_date)
    filename = f'BYBIT-{currency_pair}-{pair_sufix}-{interval}m-data-from-{start.replace(" ", "_")}-to-{end.replace(" ", "_")}.csv'

    print(f'Downloading dataset {currency_pair} {pair_sufix} in candles of {interval}m from {start} to {end}')
    print("Total number of candles is",int((int(end_date)-int(start_date))/ (60 * interval)))

    list_candle_times = list(range(start_date, end_date, int(200 * 60 * interval)))
    data = []

    for current_time in progressBar(list_candle_times, prefix = 'Progress:', suffix = 'Complete', length = 50):
        status_code = 0
        response = 1

        while(status_code != 200):
            response = requests.get(f'https://api.bybit.com/v2/public/kline/list?symbol={currency_pair}&interval={interval}&limit=200&from={current_time}')
            status_code = response.status_code
            time.sleep(0.1)

        if response.json()["result"]:
            first_candle = response.json()["result"][0]
            if end_date <= first_candle["open_time"]:
                break
            data.append([first_candle["open_time"], first_candle["open"], first_candle["high"], first_candle["low"], first_candle["close"], first_candle["volume"], int(first_candle["open_time"]) + interval * 60])
            break  # Thoát khỏi vòng lặp sau khi lấy được chỉ số đầu tiên

    df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time'])

    # Saving the CSV
    df.set_index('timestamp', inplace=True)
    df.to_csv(filename, sep=",", encoding='utf-8', index='timestamp')

    print("Download finished !!!")
# Out:
# C:\Users\tranm\AppData\Local\Temp\ipykernel_25460\3968608555.py:10: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(int(timestamp)).strftime('%d-%m-%Y %H:%M')
# Downloading dataset BTC inverse in candles of 1m from 01-09-2020 00:00 to 17-10-2024 15:05
# Total number of candles is 2171405
# Progress: |--------------------------------------------------| 0.0% Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 56
#      54     response = requests.get(f'https://api.bybit.com/v2/public/kline/list?symbol={currency_pair}&interval={interval}&limit=200&from={current_time}')
#      55     status_code = response.status_code
# ---> 56     time.sleep(0.1)
#      58 if response.json()["result"]:
#      59     first_candle = response.json()["result"][0]
#
# KeyboardInterrupt:

# %%
! pip install pybit
# Out:
# Collecting pybit
#   Using cached pybit-5.8.0-py2.py3-none-any.whl
# Requirement already satisfied: requests in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from pybit) (2.32.3)
# Collecting websocket-client (from pybit)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting pycryptodome (from pybit)
#   Using cached pycryptodome-3.21.0-cp36-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests->pybit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests->pybit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests->pybit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests->pybit) (2024.8.30)
# Using cached pycryptodome-3.21.0-cp36-abi3-win_amd64.whl (1.8 MB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Installing collected packages: websocket-client, pycryptodome, pybit
# Successfully installed pybit-5.8.0 pycryptodome-3.21.0 websocket-client-1.8.0

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tranm\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.8.30)

# %%
from pybit.unified_trading import HTTP

# %%
session = HTTP(
    testnet=False,
    api_key="epVMQ9vqe4IXIBX5CL",
    api_secret="5GSEdwSOR86mSeTs2EE0MH4dKCaObBNHXObC",
)

# %%
import requests

# Initialize the session
session = requests.Session()

# Define the API endpoint for the order book
url = "https://api.binance.com/api/v3/depth"
params = {
    "symbol": "BTCUSDT",
    "limit": 100  # Number of orders to retrieve
}

# Get the order book
response = session.get(url, params=params)
orderbook = response.json()
print(orderbook)

# Create five long USDC Options orders
payload = {"category": "option"}
orders = [{
    "symbol": "BTC-30JUN23-20000-C",
    "side": "Buy",
    "orderType": "Limit",
    "qty": "0.1",
    "price": i,
} for i in [15000, 15500, 16000, 16500, 16600]]

payload["request"] = orders

# Submit the orders in bulk (assuming you have a method to do this)
# response = session.place_batch_order(payload)
# print(response)
# Out:
# {'lastUpdateId': 53080884922, 'bids': [['67077.26000000', '2.83088000'], ['67077.14000000', '0.61571000'], ['67077.01000000', '0.00008000'], ['67077.00000000', '0.00099000'], ['67076.03000000', '0.00008000'], ['67076.02000000', '0.01475000'], ['67076.01000000', '0.16625000'], ['67076.00000000', '0.12580000'], ['67075.47000000', '0.00638000'], ['67075.36000000', '0.00008000'], ['67075.00000000', '0.02982000'], ['67074.94000000', '0.23229000'], ['67074.00000000', '0.12580000'], ['67073.40000000', '0.03560000'], ['67073.24000000', '0.00037000'], ['67072.45000000', '0.07914000'], ['67072.32000000', '0.00016000'], ['67072.01000000', '0.13778000'], ['67072.00000000', '0.12580000'], ['67071.90000000', '0.19754000'], ['67071.72000000', '0.00149000'], ['67071.52000000', '0.00100000'], ['67070.62000000', '0.00666000'], ['67070.00000000', '0.02934000'], ['67069.27000000', '0.01000000'], ['67068.96000000', '0.54866000'], ['67068.89000000', '0.32915000'], ['67068.69000000', '0.00012000'], ['67068.65000000', '0.00008000'], ['67068.45000000', '0.10722000'], ['67068.08000000', '0.03519000'], ['67068.00000000', '0.02920000'], ['67067.69000000', '0.00013000'], ['67067.52000000', '0.00038000'], ['67067.46000000', '0.29828000'], ['67067.33000000', '0.49603000'], ['67067.15000000', '0.19308000'], ['67067.10000000', '0.49603000'], ['67066.00000000', '0.02920000'], ['67065.92000000', '0.00100000'], ['67065.91000000', '0.62623000'], ['67065.73000000', '0.05389000'], ['67065.70000000', '0.17323000'], ['67065.60000000', '0.89710000'], ['67065.59000000', '0.22403000'], ['67065.53000000', '0.00038000'], ['67065.39000000', '0.04662000'], ['67065.30000000', '0.00008000'], ['67065.24000000', '0.12199000'], ['67065.08000000', '0.00103000'], ['67065.04000000', '0.49603000'], ['67064.61000000', '0.37202000'], ['67064.31000000', '0.44725000'], ['67064.21000000', '0.37951000'], ['67064.07000000', '0.49603000'], ['67064.00000000', '0.02920000'], ['67063.57000000', '0.29762000'], ['67063.47000000', '0.27532000'], ['67063.42000000', '0.21444000'], ['67063.33000000', '0.04255000'], ['67063.28000000', '0.00100000'], ['67062.00000000', '0.02920000'], ['67061.99000000', '0.00012000'], ['67061.95000000', '0.00008000'], ['67061.45000000', '0.37620000'], ['67061.19000000', '0.24000000'], ['67061.09000000', '0.06000000'], ['67061.07000000', '0.29831000'], ['67060.38000000', '0.01200000'], ['67060.20000000', '0.10453000'], ['67060.17000000', '0.00010000'], ['67060.02000000', '0.01200000'], ['67060.00000000', '0.04130000'], ['67059.90000000', '0.11926000'], ['67059.64000000', '0.01999000'], ['67059.57000000', '0.37202000'], ['67059.26000000', '0.04812000'], ['67059.18000000', '0.00223000'], ['67058.88000000', '0.00016000'], ['67058.85000000', '1.34393000'], ['67058.84000000', '1.60735000'], ['67058.83000000', '1.37628000'], ['67058.59000000', '0.00008000'], ['67058.53000000', '0.49603000'], ['67058.51000000', '0.04354000'], ['67058.39000000', '0.21444000'], ['67058.12000000', '0.22403000'], ['67058.00000000', '0.02920000'], ['67057.60000000', '1.00000000'], ['67057.06000000', '0.44643000'], ['67056.95000000', '0.02273000'], ['67056.07000000', '0.02984000'], ['67056.02000000', '0.00010000'], ['67056.00000000', '0.02920000'], ['67055.62000000', '1.34393000'], ['67055.61000000', '0.74405000'], ['67055.55000000', '0.00028000'], ['67055.40000000', '0.28338000'], ['67055.39000000', '0.29833000'], ['67055.29000000', '0.00012000']], 'asks': [['67077.27000000', '4.65483000'], ['67077.28000000', '0.01208000'], ['67077.31000000', '0.00049000'], ['67077.77000000', '0.00010000'], ['67077.90000000', '0.00010000'], ['67077.97000000', '0.06673000'], ['67077.98000000', '0.00010000'], ['67077.99000000', '0.00010000'], ['67078.00000000', '0.10919000'], ['67078.01000000', '0.10019000'], ['67078.71000000', '0.00008000'], ['67079.48000000', '0.00008000'], ['67079.65000000', '0.17840000'], ['67079.66000000', '0.24749000'], ['67079.69000000', '0.04180000'], ['67079.87000000', '0.00016000'], ['67080 ...

# %%
# Out:
# Order book for BTC-01DEC23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-01MAR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-01NOV24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-01SEP23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-02AUG24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-02FEB24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-02JUN23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-03MAY24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-03NOV23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-04AUG23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-04OCT24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-05APR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-05JAN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-05JUL24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-06OCT23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-06SEP24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-07JUL23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-07JUN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-08DEC23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-08MAR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-08SEP23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-09AUG24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-09FEB24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-09JUN23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-10MAY24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-10NOV23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-11AUG23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-11OCT24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-12APR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-12JAN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-12JUL24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-13OCT23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-13SEP24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-14JUL23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-14JUN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-15DEC23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-15MAR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-15SEP23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-16AUG24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-16FEB24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-16JUN23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-17MAY24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-17NOV23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-18AUG23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-18OCT24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-19APR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-19JAN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-19JUL24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-20OCT23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-20SEP24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-21JUL23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-21JUN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-22DEC23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-22MAR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-22SEP23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-23AUG24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-23FEB24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-23JUN23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-24MAY24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-24NOV23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-25AUG23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-25OCT24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-26APR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-26JAN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-26JUL24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-26SEP25:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-27DEC24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-27JUN25:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-27OCT23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-27SEP24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-28JUL23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-28JUN24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-28MAR25:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-29DEC23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-29MAR24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-29NOV24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-29SEP23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-30AUG24:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-30JUN23:
# {'code': -1121, 'msg': 'Invalid symbol.'}
#
#
# Order book for BTC-31MAY24:
# {'code': -1121, 'msg': 'Invalid symbol.'}

# %%
# Ryuryu's Bybit Historical Data Downloader 
# (Production Mode 6973)
# -------------------------------------
# (c) 2022 Ryan Hayabusa 
# Github: https://github.com/ryu878 
# Web: https://aadresearch.xyz/
# Discord: ryuryu#4087
# -------------------------------------
# pip install beautifulsoup4
# pip install requests

import urllib.request
import os
import re
import gzip
import time
import requests
from bs4 import BeautifulSoup


# Set the file version
ver = '1.3:02/05/23'

# Define the base URL
base_url = 'https://public.bybit.com/trading/'

# Select the start date
start_date = '2024-10-10'

# Set the list of coins
coins = []

# Create a function to download the files
def download_file(url, local_path):
    with urllib.request.urlopen(url) as response, open(local_path, 'wb') as out_file:
        data = response.read()
        out_file.write(data)


# Create a function to check if a file exists
def file_exists(local_path):
    return os.path.exists(local_path)


# Make a GET request to the base URL and parse the HTML
response = requests.get(base_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the links on the page
texts = ['BTCPERP/']
links = soup.find_all('a', string=lambda text: text in texts)
# 'BTCUSD/', 'BTCUSDT/', 

# Loop through all the links
for link in links:
    # Get the href attribute of the link
    href = link.get('href')
    # Check if the href attribute is a directory
    if href.endswith('/'):
        # Get the directory name
        dir_name = href[:-1]
        # Create the directory locally if it doesn't exist
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
        # Make a GET request to the directory URL and parse the HTML
        dir_url = base_url + href
        dir_response = requests.get(dir_url)
        dir_soup = BeautifulSoup(dir_response.text, 'html.parser')
        # Find all the CSV files in the directory
        csv_links = dir_soup.find_all(href=re.compile('.csv.gz$'))
        # Loop through all the CSV files
        for csv_link in csv_links:
            # Get the CSV file name
            csv_name = csv_link.text
            # Extract the date from the CSV file name
            csv_date = re.findall(r'\d{4}-\d{2}-\d{2}', csv_name)[0]
            # Check if the file is from or after the selected start date
            if csv_date >= start_date:
                # Construct the full URL of the CSV file
                csv_url = dir_url + csv_name
                # Construct the local path of the extracted file
                extracted_path = os.path.join(dir_name, csv_name[:-3])
                # Check if the extracted file exists locally
                if file_exists(extracted_path):
                    print('Skipping download of', csv_name, '- extracted file already exists.')
                else:
                    # Construct the local path of the archive file
                    archive_path = os.path.join(dir_name, csv_name)
                    # Download the archive file if it doesn't exist locally
                    if not file_exists(archive_path):
                        download_file(csv_url, archive_path)
                        print('Downloaded:', archive_path)
                        time.sleep(0.1)
                    # Check if the file is a gzip archive
                    if csv_name.endswith('.gz'):
                        # Open the gzip archive and extract the contents
                        with gzip.open(archive_path, 'rb') as f_in:
                            with open(extracted_path, 'wb') as f_out:
                                f_out.write(f_in.read())
                                print('Extracted:', extracted_path)
                        # Remove the archive file
                        os.remove(archive_path)
                        print('Removed:', archive_path)
                    else:
                        # Rename the file to remove the .csv extension
                        os.rename(archive_path, extracted_path)
                        print('Renamed:', archive_path, 'to', extracted_path)
            else:
                # Skip the file
                print('Skipping download of', csv_name, '- date is before start date.')
# Out:
# Skipping download of BTCPERP2023-05-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-05-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-05-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-06-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-07-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-08-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-09-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-10-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-11-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2023-12-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-01-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-02-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-03-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-04-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-05-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-06-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-07-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-08-31.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-09.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-10.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-11.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-12.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-13.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-14.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-15.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-16.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-17.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-18.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-19.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-20.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-21.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-22.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-23.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-24.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-25.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-26.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-27.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-28.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-29.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-09-30.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-01.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-02.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-03.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-04.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-05.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-06.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-07.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-08.csv.gz - date is before start date.
# Skipping download of BTCPERP2024-10-09.csv.gz - date is before start date.
# Downloaded: BTCPERP\BTCPERP2024-10-10.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-10.csv
# Removed: BTCPERP\BTCPERP2024-10-10.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-11.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-11.csv
# Removed: BTCPERP\BTCPERP2024-10-11.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-12.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-12.csv
# Removed: BTCPERP\BTCPERP2024-10-12.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-13.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-13.csv
# Removed: BTCPERP\BTCPERP2024-10-13.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-14.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-14.csv
# Removed: BTCPERP\BTCPERP2024-10-14.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-15.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-15.csv
# Removed: BTCPERP\BTCPERP2024-10-15.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-16.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-16.csv
# Removed: BTCPERP\BTCPERP2024-10-16.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-17.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-17.csv
# Removed: BTCPERP\BTCPERP2024-10-17.csv.gz
# Downloaded: BTCPERP\BTCPERP2024-10-18.csv.gz
# Extracted: BTCPERP\BTCPERP2024-10-18.csv
# Removed: BTCPERP\BTCPERP2024-10-18.csv.gz

# %%
import urllib.request
import os
import re
import gzip
import time
import requests
from bs4 import BeautifulSoup


# Set the file version
ver = '1.3:02/05/23'

# Define the base URL
base_url = 'https://public.bybit.com/kline_for_metatrader4/'

# Select the start date
start_date = '2024-6-1'

# Set the list of coins
coins = []

# Create a function to download the files
def download_file(url, local_path):
    with urllib.request.urlopen(url) as response, open(local_path, 'wb') as out_file:
        data = response.read()
        out_file.write(data)


# Create a function to check if a file exists
def file_exists(local_path):
    return os.path.exists(local_path)


# Make a GET request to the base URL and parse the HTML
response = requests.get(base_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the links on the page
texts = ['BTCUSDT/']
links = soup.find_all('a', string=lambda text: text in texts)
# 'BTCUSD/', 'BTCUSDT/', 

# Loop through all the links
for link in links:
    # Get the href attribute of the link
    href = link.get('href')
    # Check if the href attribute is a directory
    if href.endswith('/'):
        # Get the directory name
        dir_name = href[:-1]
        # Create the directory locally if it doesn't exist
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
        # Make a GET request to the directory URL and parse the HTML
        dir_url = base_url + href 
        dir_response = requests.get(dir_url)
        dir_soup = BeautifulSoup(dir_response.text, 'html.parser')
        # Find all the CSV files in the directory
        csv_links = dir_soup.find_all(href=re.compile('.csv.gz$'))
        # Loop through all the CSV files
        for csv_link in csv_links:
            # Get the CSV file name
            csv_name = csv_link.text
            # Extract the date from the CSV file name
            csv_date = re.findall(r'\d{4}-\d{2}-\d{2}', csv_name)[0]
            # Check if the file is from or after the selected start date
            if csv_date >= start_date:
                # Construct the full URL of the CSV file
                csv_url = dir_url + csv_name
                # Construct the local path of the extracted file
                extracted_path = os.path.join(dir_name, csv_name[:-3])
                # Check if the extracted file exists locally
                if file_exists(extracted_path):
                    print('Skipping download of', csv_name, '- extracted file already exists.')
                else:
                    # Construct the local path of the archive file
                    archive_path = os.path.join(dir_name, csv_name)
                    # Download the archive file if it doesn't exist locally
                    if not file_exists(archive_path):
                        download_file(csv_url, archive_path)
                        print('Downloaded:', archive_path)
                        time.sleep(0.1)
                    # Check if the file is a gzip archive
                    if csv_name.endswith('.gz'):
                        # Open the gzip archive and extract the contents
                        with gzip.open(archive_path, 'rb') as f_in:
                            with open(extracted_path, 'wb') as f_out:
                                f_out.write(f_in.read())
                                print('Extracted:', extracted_path)
                        # Remove the archive file
                        os.remove(archive_path)
                        print('Removed:', archive_path)
                    else:
                        # Rename the file to remove the .csv extension
                        os.rename(archive_path, extracted_path)
                        print('Renamed:', archive_path, 'to', extracted_path)
            else:
                # Skip the file
                print('Skipping download of', csv_name, '- date is before start date.')
